# %%
import pandas as pd
import plotly.express as px

# Test Plotly export
df = pd.DataFrame({'x': [1,2,3], 'y': [4,5,6]})
fig = px.line(df, x='x', y='y', title='Test Chart')

# Save as HTML
fig.write_html('../dashboard/test.html')
print("✓ Dashboard generation working!")
# Out:
# ✓ Dashboard generation working!

# %%
import pandas as pd

# !pip install lxml
import lxml


# Download directly from MyNeta export
url = "https://myneta.info/LokSabha2024/"
df = pd.read_html(url)[0]
df.to_excel('data/raw/lok_sabha_2024.xlsx', index=False)
# Out:
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 10
#       8 url = "https://myneta.info/LokSabha2024/"
#       9 df = pd.read_html(url)[0]
# ---> 10 df.to_excel('data/raw/lok_sabha_2024.xlsx', index=False)
#
# File C:\rkjat.in\portfolio\indian-legislature-analysis\venv\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
