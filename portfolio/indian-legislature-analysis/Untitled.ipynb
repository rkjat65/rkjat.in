# %%
# Run this in your indian-legislature-analysis folder
import os
import shutil

# Create the exact structure for GitHub
deploy_folder = 'github-deploy'
os.makedirs(f'{deploy_folder}/portfolio/indian-legislature-analysis/dashboard/charts', exist_ok=True)
os.makedirs(f'{deploy_folder}/portfolio/indian-legislature-analysis/data', exist_ok=True)

# Copy dashboard files
shutil.copytree("C:/rkjat.in/portfolio/indian-legislature-analysis/dashboard/charts", 
                f'{deploy_folder}/portfolio/indian-legislature-analysis/dashboard/charts',
                dirs_exist_ok=True)

# Copy dashboard index
shutil.copy('C:/rkjat.in/portfolio/indian-legislature-analysis/dashboard/index.html', 
            f'{deploy_folder}/portfolio/indian-legislature-analysis/dashboard/index.html')

# Copy data
shutil.copy('C:/rkjat.in/portfolio/indian-legislature-analysis/data/processed/lok_sabha_2024_cleaned.csv',
            f'{deploy_folder}/portfolio/indian-legislature-analysis/data/lok_sabha_2024_cleaned.csv')

print("✅ Files organized in 'github-deploy' folder!")
print("\nNext: Create the project page HTML")
# Out:
# ✅ Files organized in 'github-deploy' folder!
#
# Next: Create the project page HTML

# %%
import os
print(f"Current Working Directory: {os.getcwd()}")
# Out:
# Current Working Directory: C:\rkjat.in\portfolio\indian-legislature-analysis
